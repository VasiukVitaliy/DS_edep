# %%
import os

# %%
# %pwd
# Out:
# 'c:\\Users\\QSUS\\Desktop\\6_sem\\course\\EDEP\\DS_edep\\research'

# %%
os.chdir("../")
# %pwd
# Out:
# 'c:\\Users\\QSUS\\Desktop\\6_sem\\course\\EDEP\\DS_edep'

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass
class DataTransformConfig:
    root_dir: Path
    data_path: Path

# %%
from src.ds_edep.constants import *
from src.ds_edep.utils.common import read_yaml, create_directories, main_logger
# Out:
# [2026-06-07 19:44:36,867: INFO: __init__: Logger setup completed!]

# %%
class ConfigManager:
    def __init__(self,
                 config_path = CONFIG_FILE_PATH, 
                 params_path = PARAMS_FILE_PATH, 
                 schema_path = SCHEMA_FILE_PATH):
        self.config = read_yaml(config_path)
        self.params = read_yaml(params_path)
        self.schema = read_yaml(schema_path)
    
    def get_data_transformation_config(self) -> DataTransformConfig:
        cfg = self.config.data_transformation
        create_directories([cfg.root_dir])
        
        obj_config = DataTransformConfig(root_dir= cfg.root_dir,
                                         data_path = cfg.data_path)
        
        return obj_config

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
class DataTranform:
    def __init__(self, config):
        self.config = config
    
    def splitting_data(self):
        data = pd.read_csv(self.config.data_path)
        
        train, test = train_test_split(data)
        
        train.to_pd(self.config.root_dir / "train.csv", index = False)
        test.to_pd(self.config.root_dir / "test.csv", index = False)
        
        main_logger.info("Splited data into training and test sets")
        main_logger.info(train.shape)
        main_logger.info(test.shape)

        print(train.shape)
        print(test.shape)

# %%
try:
    manager = ConfigManager()
    cfg = manager.get_data_transformation_config()
    transformer = DataTranform(cfg)
    transformer.splitting_data()
except Exception as e:
    raise e
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:605, in box.box.Box.__getitem__()
#
# KeyError: 'data_trasformation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:644, in box.box.Box.__getattr__()
#
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:632, in box.box.Box.__getitem__()
#
# BoxKeyError: "'data_trasformation'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:646, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'data_trasformation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\config_box.py:29, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:660, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_trasformation'"
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:605, in box.box.Box.__getitem__()
#
# KeyError: 'data_trasformation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:644, in box.box.Box.__getattr__()
#
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:632, in box.box.Box.__getitem__()
#
# BoxKeyError: "'data_trasformation'"
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:646, in box.box.Box.__getattr__()
#
# AttributeError: 'ConfigBox' object has no attribute 'data_trasformation'
#
# The above exception was the direct cause of the following exception:
#
# BoxKeyError                               Traceback (most recent call last)
# Cell In[9], line 7
#       5     transformer.splitting_data()
#       6 except Exception as e:
# ----> 7     raise e
#
# Cell In[9], line 3
#       1 try:
#       2     manager = ConfigManager()
# ----> 3     cfg = manager.get_data_transformation_config()
#       4     transformer = DataTranform(cfg)
#       5     transformer.splitting_data()
#
# Cell In[6], line 11, in ConfigManager.get_data_transformation_config(self)
#      10 def get_data_transformation_config(self) -> DataTransformConfig:
# ---> 11     cfg = self.config.data_trasformation
#      12     create_directories([cfg.root_dir])
#      14     obj_config = DataTransformConfig(root_dir= cfg.root_dir,
#      15                                      data_path = cfg.data_path)
#
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\config_box.py:31, in box.config_box.ConfigBox.__getattr__()
#
# File c:\Users\QSUS\AppData\Local\Programs\Python\Python313\Lib\site-packages\box\box.py:660, in box.box.Box.__getattr__()
#
# BoxKeyError: "'ConfigBox' object has no attribute 'data_trasformation'"
